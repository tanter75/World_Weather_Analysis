# %%
# Dependencies and Setup
import gmaps
from citipy import citipy
import numpy as np
import pandas as pd

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
 # Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
 # Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | lasa
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | marsa matruh
# Processing Record 6 of Set 1 | hue
# Processing Record 7 of Set 1 | pisco
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | necochea
# Processing Record 13 of Set 1 | takoradi
# Processing Record 14 of Set 1 | labuhan
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | waitati
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | husavik
# Processing Record 22 of Set 1 | saint-georges
# Processing Record 23 of Set 1 | kenai
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | jasper
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | labuan
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | maunatlala
# Processing Record 32 of Set 1 | port lincoln
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | vao
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | rawson
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | foam lake
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | ecatzingo
# City not found. Skipping...
# Processing Record 43 of Set 1 | selje
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | korla
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | aras
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | ulcinj
# Processing Record 2 of Set 2 | antalaha
# Processing Record 3 of Set 2 | davidson
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | iquique
# Processing Record 10 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | teguise
# Processing Record 13 of Set 2 | waipawa
# Processing Record 14 of Set 2 | rio grande
# Processing Record 15 of Set 2 | roald
# Processing Record 16 of Set 2 | onega
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | bria
# Processing Record 19 of Set 2 | dudinka
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | nome
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | chama
# Processing Record 24 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | razole
# Processing Record 29 of Set 2 | samarai
# Processing Record 30 of Set 2 | ubinskoye
# Processing Record 31 of Set 2 | constitucion
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | wagar
# Processing Record 35 of Set 2 | aklavik
# Processing Record 36 of Set 2 | tabou
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | karpathos
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | mehamn
# Processing Record 41 of Set 2 | tevaitoa
# Processing Record 42 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 2 | hovd
# Processing Record 44 of Set 2 | caravelas
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | tsabong
# Processing Record 47 of Set 2 | lorengau
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | bartica
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | bitung
# Processing Record 8 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 3 | kyzyl-suu
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | mangrol
# Processing Record 12 of Set 3 | nuevo progreso
# Processing Record 13 of Set 3 | kieta
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | tynda
# Processing Record 17 of Set 3 | kushiro
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | micheweni
# Processing Record 21 of Set 3 | le vauclin
# Processing Record 22 of Set 3 | mercedes
# Processing Record 23 of Set 3 | ambrolauri
# Processing Record 24 of Set 3 | zhezkazgan
# Processing Record 25 of Set 3 | san luis
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | pangnirtung
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | ban tak
# Processing Record 32 of Set 3 | narsaq
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | jining
# Processing Record 35 of Set 3 | najran
# Processing Record 36 of Set 3 | half moon bay
# Processing Record 37 of Set 3 | lavrentiya
# Processing Record 38 of Set 3 | sokolo
# Processing Record 39 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 3 | beringovskiy
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | shkoder
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | chapleau
# Processing Record 45 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 3 | nyurba
# Processing Record 47 of Set 3 | jalu
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | dumas
# Processing Record 50 of Set 3 | nantucket
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | acurenam
# Processing Record 3 of Set 4 | mecca
# Processing Record 4 of Set 4 | prince rupert
# Processing Record 5 of Set 4 | aykhal
# Processing Record 6 of Set 4 | meulaboh
# Processing Record 7 of Set 4 | cassilandia
# Processing Record 8 of Set 4 | madera
# Processing Record 9 of Set 4 | truth or consequences
# Processing Record 10 of Set 4 | naze
# Processing Record 11 of Set 4 | wum
# Processing Record 12 of Set 4 | tecoanapa
# Processing Record 13 of Set 4 | manikpur
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | maceio
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | flin flon
# Processing Record 21 of Set 4 | gueret
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | sal rei
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | sungaipenuh
# Processing Record 29 of Set 4 | beihai
# Processing Record 30 of Set 4 | maniitsoq
# Processing Record 31 of Set 4 | vanavara
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | kavieng
# Processing Record 34 of Set 4 | abu samrah
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | delhi
# Processing Record 37 of Set 4 | sao joao da barra
# Processing Record 38 of Set 4 | riyadh
# Processing Record 39 of Set 4 | yellowknife
# Processing Record 40 of Set 4 | shingu
# Processing Record 41 of Set 4 | sivas
# Processing Record 42 of Set 4 | arlit
# Processing Record 43 of Set 4 | bairiki
# Processing Record 44 of Set 4 | santa ana
# Processing Record 45 of Set 4 | pochutla
# Processing Record 46 of Set 4 | puerto leguizamo
# Processing Record 47 of Set 4 | acarau
# Processing Record 48 of Set 4 | dingle
# Processing Record 49 of Set 4 | khasan
# Processing Record 50 of Set 4 | hamilton
# Processing Record 1 of Set 5 | egvekinot
# Processing Record 2 of Set 5 | kyenjojo
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | san carlos de bariloche
# Processing Record 7 of Set 5 | luang prabang
# Processing Record 8 of Set 5 | flinders
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | simao
# Processing Record 11 of Set 5 | jati
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | the valley
# Processing Record 14 of Set 5 | yumen
# Processing Record 15 of Set 5 | zyryanka
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | airai
# Processing Record 18 of Set 5 | ferrol
# Processing Record 19 of Set 5 | tianpeng
# Processing Record 20 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 5 | sorong
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | goderich
# Processing Record 24 of Set 5 | hilo
# Processing Record 25 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | verkhnyaya inta
# Processing Record 28 of Set 5 | papetoai
# Processing Record 29 of Set 5 | bom sucesso
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | satis
# Processing Record 32 of Set 5 | otradnoye
# Processing Record 33 of Set 5 | mabaruma
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | dimataling
# Processing Record 36 of Set 5 | mackay
# Processing Record 37 of Set 5 | abrau-dyurso
# Processing Record 38 of Set 5 | baykit
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | lincoln
# Processing Record 41 of Set 5 | fukue
# Processing Record 42 of Set 5 | dukhovshchina
# Processing Record 43 of Set 5 | usakos
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | kirensk
# Processing Record 46 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 5 | kruisfontein
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | saint anthony
# Processing Record 50 of Set 5 | celestun
# Processing Record 1 of Set 6 | strezhevoy
# Processing Record 2 of Set 6 | vostok
# Processing Record 3 of Set 6 | port-gentil
# Processing Record 4 of Set 6 | fereydun kenar
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | casa nova
# Processing Record 8 of Set 6 | paamiut
# Processing Record 9 of Set 6 | kintampo
# Processing Record 10 of Set 6 | arraial do cabo
# Processing Record 11 of Set 6 | bukachacha
# Processing Record 12 of Set 6 | taoudenni
# Processing Record 13 of Set 6 | kharagauli
# Processing Record 14 of Set 6 | avera
# Processing Record 15 of Set 6 | urengoy
# Processing Record 16 of Set 6 | iquitos
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | diamantino
# Processing Record 19 of Set 6 | koudougou
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | mount pleasant
# Processing Record 22 of Set 6 | novikovo
# Processing Record 23 of Set 6 | dubuque
# Processing Record 24 of Set 6 | jacareacanga
# Processing Record 25 of Set 6 | manggar
# Processing Record 26 of Set 6 | chebsara
# Processing Record 27 of Set 6 | hit
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 6 | cockburn town
# Processing Record 31 of Set 6 | deputatskiy
# Processing Record 32 of Set 6 | nurobod
# Processing Record 33 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 6 | tongliao
# Processing Record 35 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 6 | axim
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | gusinoye ozero
# Processing Record 40 of Set 6 | college
# Processing Record 41 of Set 6 | cozumel
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | broken hill
# Processing Record 44 of Set 6 | matay
# Processing Record 45 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 46 of Set 6 | sfantu gheorghe
# Processing Record 47 of Set 6 | baruun-urt
# Processing Record 48 of Set 6 | east london
# Processing Record 49 of Set 6 | oranjemund
# Processing Record 50 of Set 6 | shelburne
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | malibu
# Processing Record 3 of Set 7 | nanakuli
# Processing Record 4 of Set 7 | banda aceh
# Processing Record 5 of Set 7 | rehoboth
# Processing Record 6 of Set 7 | vitry-le-francois
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | sovetskiy
# Processing Record 10 of Set 7 | puerto ayora
# Processing Record 11 of Set 7 | edd
# Processing Record 12 of Set 7 | vila franca do campo
# Processing Record 13 of Set 7 | poli
# Processing Record 14 of Set 7 | gizycko
# Processing Record 15 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 7 | kidal
# Processing Record 17 of Set 7 | whitehorse
# Processing Record 18 of Set 7 | muisne
# Processing Record 19 of Set 7 | pokhara
# Processing Record 20 of Set 7 | bourail
# Processing Record 21 of Set 7 | wadi musa
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | tautira
# Processing Record 24 of Set 7 | kaa-khem
# Processing Record 25 of Set 7 | vanimo
# Processing Record 26 of Set 7 | northam
# Processing Record 27 of Set 7 | hatta
# Processing Record 28 of Set 7 | odweyne
# Processing Record 29 of Set 7 | suntar
# Processing Record 30 of Set 7 | borovoy
# Processing Record 31 of Set 7 | burica
# City not found. Skipping...
# Processing Record 32 of Set 7 | zalantun
# Processing Record 33 of Set 7 | palma gil
# Processing Record 34 of Set 7 | virginia beach
# Processing Record 35 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | aquiraz
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | shache
# Processing Record 40 of Set 7 | heihe
# Processing Record 41 of Set 7 | praya
# Processing Record 42 of Set 7 | saldanha
# Processing Record 43 of Set 7 | nishihara
# Processing Record 44 of Set 7 | ulladulla
# Processing Record 45 of Set 7 | huarmey
# Processing Record 46 of Set 7 | norman wells
# Processing Record 47 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 48 of Set 7 | pitimbu
# Processing Record 49 of Set 7 | kwekwe
# Processing Record 50 of Set 7 | dunda
# Processing Record 1 of Set 8 | pacific grove
# Processing Record 2 of Set 8 | cidreira
# Processing Record 3 of Set 8 | srandakan
# Processing Record 4 of Set 8 | san juan de los morros
# Processing Record 5 of Set 8 | rapar
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | port-cartier
# Processing Record 8 of Set 8 | provideniya
# Processing Record 9 of Set 8 | mmathubudukwane
# Processing Record 10 of Set 8 | lockhart
# Processing Record 11 of Set 8 | yatou
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | jatai
# Processing Record 14 of Set 8 | ban nahin
# Processing Record 15 of Set 8 | lebanon
# Processing Record 16 of Set 8 | kango
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | warrnambool
# Processing Record 19 of Set 8 | miri
# Processing Record 20 of Set 8 | naron
# Processing Record 21 of Set 8 | urumqi
# Processing Record 22 of Set 8 | mykolayivka
# Processing Record 23 of Set 8 | orgita
# Processing Record 24 of Set 8 | alofi
# Processing Record 25 of Set 8 | san cristobal
# Processing Record 26 of Set 8 | carupano
# Processing Record 27 of Set 8 | rodrigues alves
# Processing Record 28 of Set 8 | bonavista
# Processing Record 29 of Set 8 | clyde river
# Processing Record 30 of Set 8 | abha
# Processing Record 31 of Set 8 | phalombe
# Processing Record 32 of Set 8 | sharan
# Processing Record 33 of Set 8 | neiafu
# Processing Record 34 of Set 8 | praia da vitoria
# Processing Record 35 of Set 8 | sisimiut
# Processing Record 36 of Set 8 | abu dhabi
# Processing Record 37 of Set 8 | amapa
# Processing Record 38 of Set 8 | ibotirama
# Processing Record 39 of Set 8 | matagami
# Processing Record 40 of Set 8 | henties bay
# Processing Record 41 of Set 8 | cobija
# Processing Record 42 of Set 8 | trincomalee
# Processing Record 43 of Set 8 | inhambane
# Processing Record 44 of Set 8 | usinsk
# Processing Record 45 of Set 8 | magway
# Processing Record 46 of Set 8 | brindisi
# Processing Record 47 of Set 8 | umm kaddadah
# Processing Record 48 of Set 8 | zabolottya
# City not found. Skipping...
# Processing Record 49 of Set 8 | marsh harbour
# Processing Record 50 of Set 8 | progreso
# Processing Record 1 of Set 9 | yamasaki
# Processing Record 2 of Set 9 | pringsewu
# Processing Record 3 of Set 9 | dunedin
# Processing Record 4 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 9 | yulara
# Processing Record 6 of Set 9 | aksarka
# Processing Record 7 of Set 9 | hope
# Processing Record 8 of Set 9 | kuznechnoye
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | manacapuru
# Processing Record 11 of Set 9 | bethel
# Processing Record 12 of Set 9 | tilichiki
# Processing Record 13 of Set 9 | pudozh
# Processing Record 14 of Set 9 | gejiu
# Processing Record 15 of Set 9 | bom jesus
# Processing Record 16 of Set 9 | birjand
# Processing Record 17 of Set 9 | vyatskiye polyany
# Processing Record 18 of Set 9 | loandjili
# Processing Record 19 of Set 9 | jinxiang
# Processing Record 20 of Set 9 | nouakchott
# Processing Record 21 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 9 | kimbe
# Processing Record 23 of Set 9 | emerald
# Processing Record 24 of Set 9 | vanderhoof
# Processing Record 25 of Set 9 | sorland
# Processing Record 26 of Set 9 | kaoma
# Processing Record 27 of Set 9 | iralaya
# Processing Record 28 of Set 9 | alghero
# Processing Record 29 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 30 of Set 9 | campbell river
# Processing Record 31 of Set 9 | salalah
# Processing Record 32 of Set 9 | kargasok
# Processing Record 33 of Set 9 | dobryanka
# Processing Record 34 of Set 9 | camacha
# Processing Record 35 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 36 of Set 9 | kununurra
# Processing Record 37 of Set 9 | slyudyanka
# Processing Record 38 of Set 9 | xuddur
# Processing Record 39 of Set 9 | kamenka
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | cherskiy
# Processing Record 42 of Set 9 | pierre
# Processing Record 43 of Set 9 | qasigiannguit
# Processing Record 44 of Set 9 | cordoba
# Processing Record 45 of Set 9 | liniere
# City not found. Skipping...
# Processing Record 46 of Set 9 | popondetta
# Processing Record 47 of Set 9 | moron
# Processing Record 48 of Set 9 | chimbote
# Processing Record 49 of Set 9 | gigmoto
# Processing Record 50 of Set 9 | tignere
# Processing Record 1 of Set 10 | wattegama
# Processing Record 2 of Set 10 | addis zemen
# City not found. Skipping...
# Processing Record 3 of Set 10 | coxim
# Processing Record 4 of Set 10 | cotonou
# Processing Record 5 of Set 10 | pemangkat
# Processing Record 6 of Set 10 | winslow
# Processing Record 7 of Set 10 | balakhta
# Processing Record 8 of Set 10 | xining
# Processing Record 9 of Set 10 | madarounfa
# Processing Record 10 of Set 10 | sedona
# Processing Record 11 of Set 10 | la romana
# Processing Record 12 of Set 10 | champerico
# Processing Record 13 of Set 10 | kupang
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | tigzirt
# Processing Record 16 of Set 10 | hongjiang
# Processing Record 17 of Set 10 | imbituba
# Processing Record 18 of Set 10 | kaka
# Processing Record 19 of Set 10 | chakradharpur
# Processing Record 20 of Set 10 | foz
# Processing Record 21 of Set 10 | leningradskiy
# Processing Record 22 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 10 | himora
# City not found. Skipping...
# Processing Record 24 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 10 | qingyuan
# Processing Record 26 of Set 10 | tanout
# Processing Record 27 of Set 10 | payerne
# Processing Record 28 of Set 10 | havelock
# Processing Record 29 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 10 | sharjah
# Processing Record 31 of Set 10 | tonj
# Processing Record 32 of Set 10 | kalnibolotskaya
# Processing Record 33 of Set 10 | orange cove
# Processing Record 34 of Set 10 | pimentel
# Processing Record 35 of Set 10 | ust-tsilma
# Processing Record 36 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 10 | marawi
# Processing Record 38 of Set 10 | fortuna
# Processing Record 39 of Set 10 | kendari
# Processing Record 40 of Set 10 | riberalta
# Processing Record 41 of Set 10 | kanigoro
# Processing Record 42 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 43 of Set 10 | vila do maio
# Processing Record 44 of Set 10 | beckley
# Processing Record 45 of Set 10 | ust-maya
# Processing Record 46 of Set 10 | suba
# Processing Record 47 of Set 10 | igarka
# Processing Record 48 of Set 10 | tupik
# Processing Record 49 of Set 10 | fort pierce
# Processing Record 50 of Set 10 | nanzhang
# Processing Record 1 of Set 11 | tezu
# Processing Record 2 of Set 11 | pomabamba
# Processing Record 3 of Set 11 | tobermory
# Processing Record 4 of Set 11 | sabha
# Processing Record 5 of Set 11 | peabiru
# Processing Record 6 of Set 11 | ciudad bolivar
# Processing Record 7 of Set 11 | ashington
# Processing Record 8 of Set 11 | ituiutaba
# Processing Record 9 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 11 | huesca
# Processing Record 11 of Set 11 | gohpur
# Processing Record 12 of Set 11 | palana
# Processing Record 13 of Set 11 | pospelikha
# Processing Record 14 of Set 11 | saint-pierre
# Processing Record 15 of Set 11 | kapustin yar-1
# City not found. Skipping...
# Processing Record 16 of Set 11 | macomb
# Processing Record 17 of Set 11 | itoman
# Processing Record 18 of Set 11 | ballina
# Processing Record 19 of Set 11 | akyab
# Processing Record 20 of Set 11 | luwuk
# Processing Record 21 of Set 11 | jutai
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | la ronge
# Processing Record 24 of Set 11 | katobu
# Processing Record 25 of Set 11 | brae
# Processing Record 26 of Set 11 | dalvik
# Processing Record 27 of Set 11 | bah
# Processing Record 28 of Set 11 | sao filipe
# Processing Record 29 of Set 11 | tromso
# Processing Record 30 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 11 | san policarpo
# Processing Record 32 of Set 11 | kattivakkam
# Processing Record 33 of Set 11 | shimoda
# Processing Record 34 of Set 11 | maningrida
# Processing Record 35 of Set 11 | harrai
# Processing Record 36 of Set 11 | kristiansund
# Processing Record 37 of Set 11 | zatoka
# Processing Record 38 of Set 11 | mahajanga
# Processing Record 39 of Set 11 | lourdes
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | tazmalt
# Processing Record 42 of Set 11 | roblin
# Processing Record 43 of Set 11 | omuta
# Processing Record 44 of Set 11 | ozinki
# Processing Record 45 of Set 11 | los llanos de aridane
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 48 of Set 11 | atikokan
# Processing Record 49 of Set 11 | sur
# Processing Record 50 of Set 11 | limay
# Processing Record 1 of Set 12 | laguna
# Processing Record 2 of Set 12 | beipiao
# Processing Record 3 of Set 12 | saint-joseph
# Processing Record 4 of Set 12 | bara
# Processing Record 5 of Set 12 | mahbubabad
# Processing Record 6 of Set 12 | ercis
# Processing Record 7 of Set 12 | pathardi
# Processing Record 8 of Set 12 | santa engracia
# Processing Record 9 of Set 12 | salinopolis
# Processing Record 10 of Set 12 | pushkino
# Processing Record 11 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 12 | olinda
# Processing Record 13 of Set 12 | iwanai
# Processing Record 14 of Set 12 | tucupita
# Processing Record 15 of Set 12 | kampot
# Processing Record 16 of Set 12 | charters towers
# Processing Record 17 of Set 12 | biltine
# Processing Record 18 of Set 12 | roma
# Processing Record 19 of Set 12 | freeport
# Processing Record 20 of Set 12 | ler
# Processing Record 21 of Set 12 | kaeo
# Processing Record 22 of Set 12 | westport
# Processing Record 23 of Set 12 | pangkalanbuun
# Processing Record 24 of Set 12 | iranshahr
# Processing Record 25 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | moerai
# Processing Record 28 of Set 12 | mulki
# Processing Record 29 of Set 12 | dourbali
# Processing Record 30 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 12 | mirnyy
# Processing Record 32 of Set 12 | bontang
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | mezen
# Processing Record 35 of Set 12 | adrar
# Processing Record 36 of Set 12 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 37 of Set 12 | mogadishu
# Processing Record 38 of Set 12 | lesnoye
# Processing Record 39 of Set 12 | codrington
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | zheleznodorozhnyy
# Processing Record 42 of Set 12 | kondinskoye
# Processing Record 43 of Set 12 | mingshui
# Processing Record 44 of Set 12 | raudeberg
# Processing Record 45 of Set 12 | paka
# Processing Record 46 of Set 12 | hinton
# Processing Record 47 of Set 12 | les cayes
# Processing Record 48 of Set 12 | yar-sale
# Processing Record 49 of Set 12 | teknaf
# Processing Record 50 of Set 12 | katubao
# Processing Record 1 of Set 13 | talcahuano
# Processing Record 2 of Set 13 | wanlaweyn
# Processing Record 3 of Set 13 | moranbah
# Processing Record 4 of Set 13 | gazojak
# Processing Record 5 of Set 13 | angoram
# Processing Record 6 of Set 13 | nave
# Processing Record 7 of Set 13 | poum
# Processing Record 8 of Set 13 | jardim
# Processing Record 9 of Set 13 | tiznit
# Processing Record 10 of Set 13 | trn
# Processing Record 11 of Set 13 | manokwari
# Processing Record 12 of Set 13 | baglung
# Processing Record 13 of Set 13 | filingue
# Processing Record 14 of Set 13 | zabol
# Processing Record 15 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 16 of Set 13 | okha
# Processing Record 17 of Set 13 | louveira
# Processing Record 18 of Set 13 | gberia fotombu
# Processing Record 19 of Set 13 | tessalit
# Processing Record 20 of Set 13 | talnakh
# Processing Record 21 of Set 13 | churapcha
# Processing Record 22 of Set 13 | seabra
# Processing Record 23 of Set 13 | byron bay
# Processing Record 24 of Set 13 | camopi
# Processing Record 25 of Set 13 | coffs harbour
# Processing Record 26 of Set 13 | springbok
# Processing Record 27 of Set 13 | ayan
# Processing Record 28 of Set 13 | luancheng
# Processing Record 29 of Set 13 | mayo
# Processing Record 30 of Set 13 | grindavik
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | omboue
# Processing Record 33 of Set 13 | roberval
# Processing Record 34 of Set 13 | dannenberg
# Processing Record 35 of Set 13 | ninh binh
# Processing Record 36 of Set 13 | abrego
# Processing Record 37 of Set 13 | bani
# Processing Record 38 of Set 13 | inirida
# Processing Record 39 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 13 | pangai
# Processing Record 41 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 13 | high level
# Processing Record 43 of Set 13 | taft
# Processing Record 44 of Set 13 | pervomayskoye
# Processing Record 45 of Set 13 | mamallapuram
# Processing Record 46 of Set 13 | calatayud
# Processing Record 47 of Set 13 | tutoia
# Processing Record 48 of Set 13 | mikkeli
# Processing Record 49 of Set 13 | lukovetskiy
# Processing Record 50 of Set 13 | nizwa
# Processing Record 1 of Set 14 | sioux lookout
# Processing Record 2 of Set 14 | san ignacio
# Processing Record 3 of Set 14 | khani
# Processing Record 4 of Set 14 | penzance
# Processing Record 5 of Set 14 | aswan
# Processing Record 6 of Set 14 | canton
# Processing Record 7 of Set 14 | boende
# Processing Record 8 of Set 14 | rio gallegos
# Processing Record 9 of Set 14 | monrovia
# Processing Record 10 of Set 14 | yhu
# Processing Record 11 of Set 14 | salur
# Processing Record 12 of Set 14 | tateyama
# Processing Record 13 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 14 | kirkwall
# Processing Record 16 of Set 14 | reading
# Processing Record 17 of Set 14 | zharkovskiy
# Processing Record 18 of Set 14 | atar
# Processing Record 19 of Set 14 | puerto ayacucho
# Processing Record 20 of Set 14 | zhanaozen
# Processing Record 21 of Set 14 | meadow lake
# Processing Record 22 of Set 14 | kefalos
# Processing Record 23 of Set 14 | mayumba
# Processing Record 24 of Set 14 | turbat
# Processing Record 25 of Set 14 | antofagasta
# Processing Record 26 of Set 14 | sapernoye
# Processing Record 27 of Set 14 | sulurpeta
# City not found. Skipping...
# Processing Record 28 of Set 14 | zyukayka
# Processing Record 29 of Set 14 | belyy yar
# Processing Record 30 of Set 14 | mikun
# Processing Record 31 of Set 14 | nagato
# Processing Record 32 of Set 14 | kungurtug
# Processing Record 33 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 14 | nuuk
# Processing Record 35 of Set 14 | geilo
# Processing Record 36 of Set 14 | hami
# Processing Record 37 of Set 14 | sawtell
# Processing Record 38 of Set 14 | preobrazheniye
# Processing Record 39 of Set 14 | bilma
# Processing Record 40 of Set 14 | puerto escondido
# Processing Record 41 of Set 14 | lazaro cardenas
# Processing Record 42 of Set 14 | juneau
# Processing Record 43 of Set 14 | srednekolymsk
# Processing Record 44 of Set 14 | masuguru
# Processing Record 45 of Set 14 | vondrozo
# Processing Record 46 of Set 14 | beira
# Processing Record 47 of Set 14 | kangaatsiaq
# Processing Record 48 of Set 14 | nhulunbuy
# Processing Record 49 of Set 14 | kavaratti
# Processing Record 50 of Set 14 | la foa
# Processing Record 1 of Set 15 | derzhavinsk
# Processing Record 2 of Set 15 | puerto de la cruz
# Processing Record 3 of Set 15 | matelica
# Processing Record 4 of Set 15 | gobo
# Processing Record 5 of Set 15 | ilabaya
# Processing Record 6 of Set 15 | mormugao
# Processing Record 7 of Set 15 | loikaw
# Processing Record 8 of Set 15 | lakselv
# Processing Record 9 of Set 15 | havoysund
# Processing Record 10 of Set 15 | pemba
# Processing Record 11 of Set 15 | lagos
# Processing Record 12 of Set 15 | santa rosa
# Processing Record 13 of Set 15 | nogliki
# Processing Record 14 of Set 15 | balikpapan
# Processing Record 15 of Set 15 | comodoro rivadavia
# Processing Record 16 of Set 15 | gondar
# Processing Record 17 of Set 15 | cradock
# Processing Record 18 of Set 15 | cayenne
# Processing Record 19 of Set 15 | mundargi
# Processing Record 20 of Set 15 | rantepao
# Processing Record 21 of Set 15 | suamico
# Processing Record 22 of Set 15 | katsina
# Processing Record 23 of Set 15 | yuxia
# Processing Record 24 of Set 15 | ust-omchug
# Processing Record 25 of Set 15 | dhidhdhoo
# Processing Record 26 of Set 15 | troitskoye
# Processing Record 27 of Set 15 | payakumbuh
# Processing Record 28 of Set 15 | amuntai
# Processing Record 29 of Set 15 | ketchikan
# Processing Record 30 of Set 15 | eregli
# Processing Record 31 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 15 | whitley bay
# Processing Record 33 of Set 15 | salto
# Processing Record 34 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 15 | novoseleznevo
# Processing Record 36 of Set 15 | luocheng
# Processing Record 37 of Set 15 | deer lake
# Processing Record 38 of Set 15 | torva
# Processing Record 39 of Set 15 | dwarka
# Processing Record 40 of Set 15 | asau
# Processing Record 41 of Set 15 | sorvag
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
 # Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
 city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Kapaa  22.0752 -159.3190     86.32           clear sky        67
# 1          Lasa  46.6166   10.7002     59.88    scattered clouds        92
# 2  Punta Arenas -53.1500  -70.9167     42.91     overcast clouds        93
# 3       Rikitea -23.1203 -134.9692     74.68          light rain        79
# 4  Marsa Matruh  31.3525   27.2453     75.40           clear sky        78
# 5           Hue  16.4667  107.6000     86.11          few clouds        66
# 6         Pisco -13.7000  -76.2167     62.65     overcast clouds        77
# 7         Vaini -21.2000 -175.2000     75.36    scattered clouds        73
# 8    Nanortalik  60.1432  -45.2371     49.93          light rain        95
# 9     Busselton -33.6500  115.3333     58.05          few clouds        76
#
#    Cloudiness  Wind Speed Country
# 0           1        4.00      US
# 1          43        7.31      IT
# 2          90        8.05      CL
# 3          54       14.63      PF
# 4           0        3.44      EG
# 5          20        5.75      VN
# 6          90       14.97      PE
# 7          40       11.50      TO
# 8         100       13.56      GL
# 9          22       10.58      AU

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.0752 -159.3190     86.32        67           1
# 1          Lasa      IT  46.6166   10.7002     59.88        92          43
# 2  Punta Arenas      CL -53.1500  -70.9167     42.91        93          90
# 3       Rikitea      PF -23.1203 -134.9692     74.68        79          54
# 4  Marsa Matruh      EG  31.3525   27.2453     75.40        78           0
# 5           Hue      VN  16.4667  107.6000     86.11        66          20
# 6         Pisco      PE -13.7000  -76.2167     62.65        77          90
# 7         Vaini      TO -21.2000 -175.2000     75.36        73          40
# 8    Nanortalik      GL  60.1432  -45.2371     49.93        95         100
# 9     Busselton      AU -33.6500  115.3333     58.05        76          22
#
#    Wind Speed Current Description
# 0        4.00           clear sky
# 1        7.31    scattered clouds
# 2        8.05     overcast clouds
# 3       14.63          light rain
# 4        3.44           clear sky
# 5        5.75          few clouds
# 6       14.97     overcast clouds
# 7       11.50    scattered clouds
# 8       13.56          light rain
# 9       10.58          few clouds

# %%
 city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(r'C:\Users\tante\dabc\Week_6 Challenge\Weather_Database\WeatherPy_Database.csv', index = False)
