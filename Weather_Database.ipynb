# %%
# Dependencies and Setup
import gmaps
from citipy import citipy
import numpy as np
import pandas as pd

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
 # Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
 # Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 786

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | yinchuan
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | kerepehi
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | walvis bay
# Processing Record 12 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | kasur
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | peniche
# Processing Record 18 of Set 1 | jiaozuo
# Processing Record 19 of Set 1 | north battleford
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | ocampo
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | suez
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | bilibino
# Processing Record 27 of Set 1 | sola
# Processing Record 28 of Set 1 | priargunsk
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | lagoa
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | olonets
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | kendari
# Processing Record 45 of Set 1 | port lincoln
# Processing Record 46 of Set 1 | coihaique
# Processing Record 47 of Set 1 | byron bay
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | kurayoshi
# Processing Record 1 of Set 2 | owando
# Processing Record 2 of Set 2 | gulariya
# Processing Record 3 of Set 2 | biak
# Processing Record 4 of Set 2 | muroto
# Processing Record 5 of Set 2 | imeni poliny osipenko
# Processing Record 6 of Set 2 | cap malheureux
# Processing Record 7 of Set 2 | salalah
# Processing Record 8 of Set 2 | qasigiannguit
# Processing Record 9 of Set 2 | harlingen
# Processing Record 10 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 2 | san quintin
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | tuatapere
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 2 | ixtapa
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | taoudenni
# Processing Record 20 of Set 2 | camacha
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | babol
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | salihorsk
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | prainha
# Processing Record 28 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | fort nelson
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | savalou
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | mitu
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 2 | muisne
# Processing Record 39 of Set 2 | auki
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | cherskiy
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | kousseri
# Processing Record 44 of Set 2 | chiredzi
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | hambantota
# Processing Record 47 of Set 2 | chelmsford
# Processing Record 48 of Set 2 | inverell
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | banamba
# Processing Record 2 of Set 3 | nishihara
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | marawi
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | vanimo
# Processing Record 9 of Set 3 | labuan
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | sinnamary
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | babu
# Processing Record 16 of Set 3 | lavrentiya
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | north bend
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | coahuayana
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | ugoofaaru
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | pipar
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 3 | talara
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | marsa matruh
# Processing Record 31 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | manggar
# Processing Record 34 of Set 3 | neepawa
# Processing Record 35 of Set 3 | mbekenyera
# Processing Record 36 of Set 3 | hualmay
# Processing Record 37 of Set 3 | abalak
# Processing Record 38 of Set 3 | grand gaube
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | belinskiy
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | mount hagen
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | taseyevo
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | lahat
# Processing Record 2 of Set 4 | ayan
# Processing Record 3 of Set 4 | boguchany
# Processing Record 4 of Set 4 | tortoli
# Processing Record 5 of Set 4 | zhigansk
# Processing Record 6 of Set 4 | khorinsk
# Processing Record 7 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 4 | ulaangom
# Processing Record 9 of Set 4 | nador
# Processing Record 10 of Set 4 | wisconsin rapids
# Processing Record 11 of Set 4 | quimperle
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | fairbanks
# Processing Record 17 of Set 4 | damietta
# Processing Record 18 of Set 4 | sur
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | san vicente
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | faya
# Processing Record 24 of Set 4 | wilmington
# Processing Record 25 of Set 4 | baikunthpur
# Processing Record 26 of Set 4 | kostomuksha
# Processing Record 27 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 4 | deqing
# Processing Record 30 of Set 4 | port-gentil
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | laem sing
# Processing Record 34 of Set 4 | kaitangata
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | ereymentau
# Processing Record 37 of Set 4 | grindavik
# Processing Record 38 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | dawson
# Processing Record 42 of Set 4 | paamiut
# Processing Record 43 of Set 4 | sirsilla
# Processing Record 44 of Set 4 | waingapu
# Processing Record 45 of Set 4 | kolokani
# Processing Record 46 of Set 4 | mananjary
# Processing Record 47 of Set 4 | tilichiki
# Processing Record 48 of Set 4 | kiunga
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | tezu
# Processing Record 1 of Set 5 | umm jarr
# City not found. Skipping...
# Processing Record 2 of Set 5 | mount isa
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | mar del plata
# Processing Record 5 of Set 5 | santarem
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | matipo
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | cabedelo
# Processing Record 11 of Set 5 | camacupa
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | falkoping
# City not found. Skipping...
# Processing Record 14 of Set 5 | yima
# Processing Record 15 of Set 5 | kisoro
# Processing Record 16 of Set 5 | elko
# Processing Record 17 of Set 5 | verkhoyansk
# Processing Record 18 of Set 5 | hacienda
# Processing Record 19 of Set 5 | kirakira
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | trairi
# Processing Record 22 of Set 5 | saint-philippe
# Processing Record 23 of Set 5 | raudeberg
# Processing Record 24 of Set 5 | trincomalee
# Processing Record 25 of Set 5 | navan
# Processing Record 26 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 5 | constitucion
# Processing Record 28 of Set 5 | puerto escondido
# Processing Record 29 of Set 5 | mabaruma
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | bethel
# Processing Record 35 of Set 5 | eyl
# Processing Record 36 of Set 5 | la serena
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 5 | cacapava do sul
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | acapulco
# Processing Record 45 of Set 5 | urumqi
# Processing Record 46 of Set 5 | belaya gora
# Processing Record 47 of Set 5 | artesia
# Processing Record 48 of Set 5 | hassleholm
# Processing Record 49 of Set 5 | krasnyy kholm
# Processing Record 50 of Set 5 | catamarca
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | gigmoto
# Processing Record 3 of Set 6 | goderich
# Processing Record 4 of Set 6 | santa rosa
# Processing Record 5 of Set 6 | hovd
# Processing Record 6 of Set 6 | moron
# Processing Record 7 of Set 6 | betanzos
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | kahului
# Processing Record 10 of Set 6 | nome
# Processing Record 11 of Set 6 | qaanaaq
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | lompoc
# Processing Record 14 of Set 6 | ludwigsfelde
# Processing Record 15 of Set 6 | christchurch
# Processing Record 16 of Set 6 | republic
# Processing Record 17 of Set 6 | willowmore
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | sungaipenuh
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | zhangzhou
# Processing Record 22 of Set 6 | esso
# Processing Record 23 of Set 6 | altea
# Processing Record 24 of Set 6 | buchanan
# Processing Record 25 of Set 6 | hami
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | camabatela
# Processing Record 28 of Set 6 | kayerkan
# Processing Record 29 of Set 6 | bogorodskoye
# Processing Record 30 of Set 6 | nakusp
# Processing Record 31 of Set 6 | vale da amoreira
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | magdagachi
# Processing Record 34 of Set 6 | yuli
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | achiotal
# City not found. Skipping...
# Processing Record 37 of Set 6 | la romana
# Processing Record 38 of Set 6 | brandon
# Processing Record 39 of Set 6 | isla mujeres
# Processing Record 40 of Set 6 | maiduguri
# Processing Record 41 of Set 6 | geelong
# Processing Record 42 of Set 6 | murwillumbah
# Processing Record 43 of Set 6 | victoria
# Processing Record 44 of Set 6 | ahipara
# Processing Record 45 of Set 6 | mitsamiouli
# Processing Record 46 of Set 6 | manica
# Processing Record 47 of Set 6 | shingu
# Processing Record 48 of Set 6 | erenhot
# Processing Record 49 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 6 | ponta delgada
# Processing Record 1 of Set 7 | luanda
# Processing Record 2 of Set 7 | haines junction
# Processing Record 3 of Set 7 | brownwood
# Processing Record 4 of Set 7 | saint anthony
# Processing Record 5 of Set 7 | cayenne
# Processing Record 6 of Set 7 | berlevag
# Processing Record 7 of Set 7 | sept-iles
# Processing Record 8 of Set 7 | livno
# Processing Record 9 of Set 7 | cabo san lucas
# Processing Record 10 of Set 7 | ariquemes
# Processing Record 11 of Set 7 | rafai
# Processing Record 12 of Set 7 | katete
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | lugovoy
# Processing Record 15 of Set 7 | omsukchan
# Processing Record 16 of Set 7 | westport
# Processing Record 17 of Set 7 | hurghada
# Processing Record 18 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 7 | kokopo
# Processing Record 20 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 7 | mangrol
# Processing Record 22 of Set 7 | pevek
# Processing Record 23 of Set 7 | padang
# Processing Record 24 of Set 7 | bereda
# Processing Record 25 of Set 7 | noumea
# Processing Record 26 of Set 7 | kloulklubed
# Processing Record 27 of Set 7 | maceio
# Processing Record 28 of Set 7 | aksarka
# Processing Record 29 of Set 7 | atyrau
# Processing Record 30 of Set 7 | hay river
# Processing Record 31 of Set 7 | balkanabat
# Processing Record 32 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 7 | souillac
# Processing Record 34 of Set 7 | baykit
# Processing Record 35 of Set 7 | ende
# Processing Record 36 of Set 7 | buraydah
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | makat
# Processing Record 39 of Set 7 | manavalakurichi
# Processing Record 40 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | sayyan
# Processing Record 43 of Set 7 | deputatskiy
# Processing Record 44 of Set 7 | turangi
# Processing Record 45 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 7 | wuwei
# Processing Record 47 of Set 7 | namatanai
# Processing Record 48 of Set 7 | melilla
# Processing Record 49 of Set 7 | richards bay
# Processing Record 50 of Set 7 | shar
# Processing Record 1 of Set 8 | dayong
# Processing Record 2 of Set 8 | sexsmith
# Processing Record 3 of Set 8 | sivas
# Processing Record 4 of Set 8 | barranca
# Processing Record 5 of Set 8 | tarakan
# Processing Record 6 of Set 8 | vila franca do campo
# Processing Record 7 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | nuevo casas grandes
# Processing Record 10 of Set 8 | celestun
# Processing Record 11 of Set 8 | burica
# City not found. Skipping...
# Processing Record 12 of Set 8 | cairns
# Processing Record 13 of Set 8 | bowmore
# Processing Record 14 of Set 8 | istok
# Processing Record 15 of Set 8 | beringovskiy
# Processing Record 16 of Set 8 | mount gambier
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | liberal
# Processing Record 19 of Set 8 | kungurtug
# Processing Record 20 of Set 8 | oktyabrskiy
# Processing Record 21 of Set 8 | tonj
# Processing Record 22 of Set 8 | ruian
# City not found. Skipping...
# Processing Record 23 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | barcelos
# Processing Record 25 of Set 8 | armidale
# Processing Record 26 of Set 8 | flinders
# Processing Record 27 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 8 | karratha
# Processing Record 29 of Set 8 | kenai
# Processing Record 30 of Set 8 | vargem alta
# Processing Record 31 of Set 8 | kaeo
# Processing Record 32 of Set 8 | klaksvik
# Processing Record 33 of Set 8 | ust-karsk
# Processing Record 34 of Set 8 | sechura
# Processing Record 35 of Set 8 | murray bridge
# Processing Record 36 of Set 8 | sisimiut
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | thurso
# Processing Record 39 of Set 8 | mehriz
# Processing Record 40 of Set 8 | xiuyan
# Processing Record 41 of Set 8 | pochutla
# Processing Record 42 of Set 8 | pavlodar
# Processing Record 43 of Set 8 | marfino
# Processing Record 44 of Set 8 | vestmannaeyjar
# Processing Record 45 of Set 8 | puerto colombia
# Processing Record 46 of Set 8 | verkhnevilyuysk
# Processing Record 47 of Set 8 | yuanping
# Processing Record 48 of Set 8 | shelburne
# Processing Record 49 of Set 8 | herat
# Processing Record 50 of Set 8 | san jose
# Processing Record 1 of Set 9 | brigantine
# Processing Record 2 of Set 9 | galapa
# Processing Record 3 of Set 9 | stornoway
# Processing Record 4 of Set 9 | takoradi
# Processing Record 5 of Set 9 | iranshahr
# Processing Record 6 of Set 9 | shellbrook
# Processing Record 7 of Set 9 | honningsvag
# Processing Record 8 of Set 9 | beroroha
# Processing Record 9 of Set 9 | eureka
# Processing Record 10 of Set 9 | sri aman
# Processing Record 11 of Set 9 | nisia floresta
# Processing Record 12 of Set 9 | erkrath
# Processing Record 13 of Set 9 | wexford
# Processing Record 14 of Set 9 | kurchum
# Processing Record 15 of Set 9 | zirandaro
# Processing Record 16 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 9 | waipawa
# Processing Record 18 of Set 9 | lata
# Processing Record 19 of Set 9 | akersberga
# Processing Record 20 of Set 9 | gorontalo
# Processing Record 21 of Set 9 | botwood
# Processing Record 22 of Set 9 | merauke
# Processing Record 23 of Set 9 | debre sina
# Processing Record 24 of Set 9 | great yarmouth
# Processing Record 25 of Set 9 | uruzgan
# Processing Record 26 of Set 9 | kangaatsiaq
# Processing Record 27 of Set 9 | ayorou
# Processing Record 28 of Set 9 | bukachacha
# Processing Record 29 of Set 9 | eirunepe
# Processing Record 30 of Set 9 | nioro
# Processing Record 31 of Set 9 | talaya
# Processing Record 32 of Set 9 | sergeyevka
# Processing Record 33 of Set 9 | sabha
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | xining
# Processing Record 36 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 9 | laguna
# Processing Record 38 of Set 9 | kangasala
# Processing Record 39 of Set 9 | gezing
# Processing Record 40 of Set 9 | alice springs
# Processing Record 41 of Set 9 | palmer
# Processing Record 42 of Set 9 | pathankot
# Processing Record 43 of Set 9 | morvi
# Processing Record 44 of Set 9 | cam ranh
# Processing Record 45 of Set 9 | parintins
# Processing Record 46 of Set 9 | nizhniy kuranakh
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | horizontina
# Processing Record 49 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 9 | stephenville crossing
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | havoysund
# Processing Record 3 of Set 10 | plettenberg bay
# Processing Record 4 of Set 10 | paarl
# Processing Record 5 of Set 10 | monrovia
# Processing Record 6 of Set 10 | samarai
# Processing Record 7 of Set 10 | baruun-urt
# Processing Record 8 of Set 10 | vinh
# Processing Record 9 of Set 10 | maseru
# Processing Record 10 of Set 10 | jambi
# Processing Record 11 of Set 10 | hushitai
# Processing Record 12 of Set 10 | olafsvik
# Processing Record 13 of Set 10 | kochi
# Processing Record 14 of Set 10 | san bartolome de tirajana
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | shimoda
# Processing Record 17 of Set 10 | miaoli
# Processing Record 18 of Set 10 | bamako
# Processing Record 19 of Set 10 | spornoye
# Processing Record 20 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 21 of Set 10 | mugur-aksy
# Processing Record 22 of Set 10 | mayor pablo lagerenza
# Processing Record 23 of Set 10 | maloy
# Processing Record 24 of Set 10 | praia
# Processing Record 25 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 10 | jalu
# Processing Record 28 of Set 10 | caluquembe
# Processing Record 29 of Set 10 | vao
# Processing Record 30 of Set 10 | ostrovnoy
# Processing Record 31 of Set 10 | winnemucca
# Processing Record 32 of Set 10 | pirovskoye
# Processing Record 33 of Set 10 | rundu
# Processing Record 34 of Set 10 | llandrindod wells
# Processing Record 35 of Set 10 | zunyi
# Processing Record 36 of Set 10 | yantal
# Processing Record 37 of Set 10 | port blair
# Processing Record 38 of Set 10 | makakilo city
# Processing Record 39 of Set 10 | san patricio
# Processing Record 40 of Set 10 | bontang
# Processing Record 41 of Set 10 | kieta
# Processing Record 42 of Set 10 | dhupgari
# Processing Record 43 of Set 10 | batagay-alyta
# Processing Record 44 of Set 10 | turgenevo
# Processing Record 45 of Set 10 | pimentel
# Processing Record 46 of Set 10 | margate
# Processing Record 47 of Set 10 | san policarpo
# Processing Record 48 of Set 10 | kushima
# Processing Record 49 of Set 10 | ardu
# Processing Record 50 of Set 10 | katherine
# Processing Record 1 of Set 11 | tshikapa
# Processing Record 2 of Set 11 | sovetskiy
# Processing Record 3 of Set 11 | senanga
# Processing Record 4 of Set 11 | quelimane
# Processing Record 5 of Set 11 | tamasi
# Processing Record 6 of Set 11 | broome
# Processing Record 7 of Set 11 | luau
# Processing Record 8 of Set 11 | seoul
# Processing Record 9 of Set 11 | husavik
# Processing Record 10 of Set 11 | pacific grove
# Processing Record 11 of Set 11 | kaiu
# Processing Record 12 of Set 11 | namibe
# Processing Record 13 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 11 | puerto asis
# Processing Record 15 of Set 11 | goure
# Processing Record 16 of Set 11 | banjar
# Processing Record 17 of Set 11 | turka
# Processing Record 18 of Set 11 | ulladulla
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | aracaju
# Processing Record 21 of Set 11 | huarmey
# Processing Record 22 of Set 11 | tura
# Processing Record 23 of Set 11 | olinda
# Processing Record 24 of Set 11 | fereydunshahr
# Processing Record 25 of Set 11 | berbera
# Processing Record 26 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 11 | korla
# Processing Record 28 of Set 11 | almaznyy
# Processing Record 29 of Set 11 | port dover
# Processing Record 30 of Set 11 | agadez
# Processing Record 31 of Set 11 | poddorye
# Processing Record 32 of Set 11 | labrea
# Processing Record 33 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 11 | itarema
# Processing Record 35 of Set 11 | qaqortoq
# Processing Record 36 of Set 11 | bathsheba
# Processing Record 37 of Set 11 | cobija
# Processing Record 38 of Set 11 | alekseyevsk
# Processing Record 39 of Set 11 | monte alegre
# Processing Record 40 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | the valley
# Processing Record 43 of Set 11 | antalaha
# Processing Record 44 of Set 11 | harper
# Processing Record 45 of Set 11 | nizwa
# Processing Record 46 of Set 11 | forbesganj
# Processing Record 47 of Set 11 | aklavik
# Processing Record 48 of Set 11 | kodinsk
# Processing Record 49 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 11 | aitape
# Processing Record 1 of Set 12 | antofagasta
# Processing Record 2 of Set 12 | salisbury
# Processing Record 3 of Set 12 | wajir
# Processing Record 4 of Set 12 | bac lieu
# Processing Record 5 of Set 12 | ramnagar
# Processing Record 6 of Set 12 | pamplona
# Processing Record 7 of Set 12 | gushikawa
# Processing Record 8 of Set 12 | itoman
# Processing Record 9 of Set 12 | danane
# Processing Record 10 of Set 12 | bemidji
# Processing Record 11 of Set 12 | itupiranga
# Processing Record 12 of Set 12 | yeppoon
# Processing Record 13 of Set 12 | cheyenne
# Processing Record 14 of Set 12 | zapolyarnyy
# Processing Record 15 of Set 12 | kattivakkam
# Processing Record 16 of Set 12 | ganzhou
# Processing Record 17 of Set 12 | hasaki
# Processing Record 18 of Set 12 | angoram
# Processing Record 19 of Set 12 | stromness
# Processing Record 20 of Set 12 | svetlogorsk
# Processing Record 21 of Set 12 | warri
# Processing Record 22 of Set 12 | rocha
# Processing Record 23 of Set 12 | beaufort
# Processing Record 24 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 12 | miandrivazo
# Processing Record 26 of Set 12 | krasnoborsk
# Processing Record 27 of Set 12 | rayevskiy
# Processing Record 28 of Set 12 | atambua
# Processing Record 29 of Set 12 | wakkanai
# Processing Record 30 of Set 12 | atar
# Processing Record 31 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 12 | basco
# Processing Record 35 of Set 12 | savonlinna
# Processing Record 36 of Set 12 | kuhdasht
# Processing Record 37 of Set 12 | port macquarie
# Processing Record 38 of Set 12 | luwuk
# Processing Record 39 of Set 12 | kristiinankaupunki
# Processing Record 40 of Set 12 | kurtamysh
# Processing Record 41 of Set 12 | porto velho
# Processing Record 42 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 12 | colac
# Processing Record 44 of Set 12 | sitka
# Processing Record 45 of Set 12 | moree
# Processing Record 46 of Set 12 | kudahuvadhoo
# Processing Record 47 of Set 12 | leh
# Processing Record 48 of Set 12 | hirara
# Processing Record 49 of Set 12 | aykhal
# Processing Record 50 of Set 12 | boa vista
# Processing Record 1 of Set 13 | parabel
# Processing Record 2 of Set 13 | sena madureira
# Processing Record 3 of Set 13 | fairhaven
# Processing Record 4 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 13 | kharhial
# Processing Record 6 of Set 13 | karur
# Processing Record 7 of Set 13 | bonavista
# Processing Record 8 of Set 13 | okha
# Processing Record 9 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 13 | manyana
# Processing Record 11 of Set 13 | kielce
# Processing Record 12 of Set 13 | havre-saint-pierre
# Processing Record 13 of Set 13 | portland
# Processing Record 14 of Set 13 | dangriga
# Processing Record 15 of Set 13 | inirida
# Processing Record 16 of Set 13 | wanaka
# Processing Record 17 of Set 13 | belyy yar
# Processing Record 18 of Set 13 | lisakovsk
# Processing Record 19 of Set 13 | angoche
# Processing Record 20 of Set 13 | sioux lookout
# Processing Record 21 of Set 13 | mindif
# Processing Record 22 of Set 13 | klyuchi
# Processing Record 23 of Set 13 | garowe
# Processing Record 24 of Set 13 | curaca
# Processing Record 25 of Set 13 | gryazovets
# Processing Record 26 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 13 | yakeshi
# Processing Record 28 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 13 | presidencia roque saenz pena
# Processing Record 31 of Set 13 | codrington
# Processing Record 32 of Set 13 | manokwari
# Processing Record 33 of Set 13 | half moon bay
# Processing Record 34 of Set 13 | poya
# Processing Record 35 of Set 13 | ati
# Processing Record 36 of Set 13 | luorong
# Processing Record 37 of Set 13 | ciudad bolivar
# Processing Record 38 of Set 13 | makaha
# Processing Record 39 of Set 13 | sambava
# Processing Record 40 of Set 13 | pinheiro machado
# Processing Record 41 of Set 13 | araouane
# Processing Record 42 of Set 13 | laurel
# Processing Record 43 of Set 13 | kralendijk
# Processing Record 44 of Set 13 | poso
# Processing Record 45 of Set 13 | preobrazheniye
# Processing Record 46 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 47 of Set 13 | jasper
# Processing Record 48 of Set 13 | maragogi
# Processing Record 49 of Set 13 | baculin
# Processing Record 50 of Set 13 | bilma
# Processing Record 1 of Set 14 | arroyo
# Processing Record 2 of Set 14 | sabang
# Processing Record 3 of Set 14 | birao
# Processing Record 4 of Set 14 | muskogee
# Processing Record 5 of Set 14 | khasan
# Processing Record 6 of Set 14 | kaoma
# Processing Record 7 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 8 of Set 14 | urusha
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | scunthorpe
# Processing Record 11 of Set 14 | pitimbu
# Processing Record 12 of Set 14 | wajima
# Processing Record 13 of Set 14 | sindor
# Processing Record 14 of Set 14 | mecca
# Processing Record 15 of Set 14 | kalmar
# Processing Record 16 of Set 14 | sao francisco
# Processing Record 17 of Set 14 | san cristobal
# Processing Record 18 of Set 14 | makung
# City not found. Skipping...
# Processing Record 19 of Set 14 | ambilobe
# Processing Record 20 of Set 14 | abu samrah
# Processing Record 21 of Set 14 | churapcha
# Processing Record 22 of Set 14 | riyadh
# Processing Record 23 of Set 14 | along
# Processing Record 24 of Set 14 | asfi
# Processing Record 25 of Set 14 | road town
# Processing Record 26 of Set 14 | pedernales
# Processing Record 27 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 14 | pucara
# Processing Record 29 of Set 14 | san andres
# Processing Record 30 of Set 14 | muravlenko
# Processing Record 31 of Set 14 | neryungri
# Processing Record 32 of Set 14 | chara
# Processing Record 33 of Set 14 | tual
# Processing Record 34 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 14 | shiringushi
# Processing Record 36 of Set 14 | morros
# Processing Record 37 of Set 14 | zvishavane
# Processing Record 38 of Set 14 | henties bay
# Processing Record 39 of Set 14 | kozhevnikovo
# Processing Record 40 of Set 14 | saint-joseph
# Processing Record 41 of Set 14 | tutoia
# Processing Record 42 of Set 14 | lac du bonnet
# Processing Record 43 of Set 14 | luganville
# Processing Record 44 of Set 14 | cartagena
# Processing Record 45 of Set 14 | ercis
# Processing Record 46 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 14 | redcar
# Processing Record 48 of Set 14 | washougal
# Processing Record 49 of Set 14 | vysokogornyy
# Processing Record 50 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 15 | daru
# Processing Record 2 of Set 15 | mackay
# Processing Record 3 of Set 15 | vuktyl
# Processing Record 4 of Set 15 | adjumani
# Processing Record 5 of Set 15 | zouxian
# City not found. Skipping...
# Processing Record 6 of Set 15 | pontianak
# Processing Record 7 of Set 15 | borogontsy
# Processing Record 8 of Set 15 | bati
# Processing Record 9 of Set 15 | san vicente de canete
# Processing Record 10 of Set 15 | altamira
# Processing Record 11 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 12 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 13 of Set 15 | cedar city
# Processing Record 14 of Set 15 | banes
# Processing Record 15 of Set 15 | monterey
# Processing Record 16 of Set 15 | iguape
# Processing Record 17 of Set 15 | sabinopolis
# Processing Record 18 of Set 15 | tecoanapa
# Processing Record 19 of Set 15 | tianpeng
# Processing Record 20 of Set 15 | port pirie
# Processing Record 21 of Set 15 | lagos
# Processing Record 22 of Set 15 | abbeville
# Processing Record 23 of Set 15 | nieuw amsterdam
# Processing Record 24 of Set 15 | turayf
# Processing Record 25 of Set 15 | southbridge
# Processing Record 26 of Set 15 | san juan
# Processing Record 27 of Set 15 | chesma
# Processing Record 28 of Set 15 | majene
# Processing Record 29 of Set 15 | celle
# Processing Record 30 of Set 15 | tainan
# Processing Record 31 of Set 15 | khonsa
# Processing Record 32 of Set 15 | wageningen
# Processing Record 33 of Set 15 | port augusta
# Processing Record 34 of Set 15 | bairiki
# Processing Record 35 of Set 15 | freising
# Processing Record 36 of Set 15 | rosarito
# Processing Record 37 of Set 15 | chauk
# Processing Record 38 of Set 15 | red bluff
# Processing Record 39 of Set 15 | okhotsk
# Processing Record 40 of Set 15 | callaguip
# Processing Record 41 of Set 15 | kurumkan
# Processing Record 42 of Set 15 | oboyan
# Processing Record 43 of Set 15 | port hedland
# Processing Record 44 of Set 15 | palembang
# Processing Record 45 of Set 15 | qarchi gak
# Processing Record 46 of Set 15 | novopavlovka
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | anchorage
# Processing Record 49 of Set 15 | isangel
# Processing Record 50 of Set 15 | thinadhoo
# Processing Record 1 of Set 16 | orlik
# Processing Record 2 of Set 16 | xinmin
# Processing Record 3 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 16 | wangqing
# Processing Record 5 of Set 16 | sheffield lake
# Processing Record 6 of Set 16 | marsabit
# Processing Record 7 of Set 16 | madison
# Processing Record 8 of Set 16 | bonfim
# Processing Record 9 of Set 16 | khani
# Processing Record 10 of Set 16 | lazaro cardenas
# Processing Record 11 of Set 16 | katipunan
# Processing Record 12 of Set 16 | huilong
# Processing Record 13 of Set 16 | vanavara
# Processing Record 14 of Set 16 | platanos
# Processing Record 15 of Set 16 | nazilli
# Processing Record 16 of Set 16 | zhuzhou
# Processing Record 17 of Set 16 | lossiemouth
# Processing Record 18 of Set 16 | laguna de perlas
# Processing Record 19 of Set 16 | dawei
# Processing Record 20 of Set 16 | dakar
# Processing Record 21 of Set 16 | lishui
# Processing Record 22 of Set 16 | zhigalovo
# Processing Record 23 of Set 16 | contamana
# Processing Record 24 of Set 16 | prince rupert
# Processing Record 25 of Set 16 | shache
# Processing Record 26 of Set 16 | gat
# Processing Record 27 of Set 16 | sakaiminato
# Processing Record 28 of Set 16 | hervey bay
# Processing Record 29 of Set 16 | virginia beach
# Processing Record 30 of Set 16 | anadyr
# Processing Record 31 of Set 16 | bizhbulyak
# Processing Record 32 of Set 16 | glendive
# Processing Record 33 of Set 16 | deseronto
# Processing Record 34 of Set 16 | pombas
# Processing Record 35 of Set 16 | la ronge
# Processing Record 36 of Set 16 | tochio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 715

# %%
 # Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
 city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Lebu -37.6167  -73.6500      7.80           clear sky        87
# 1  Yellowknife  62.4560 -114.3525     20.29       broken clouds        64
# 2   Chokurdakh  70.6333  147.9167      7.62     overcast clouds        67
# 3    Cape Town -33.9258   18.4232     10.49           clear sky        75
# 4  Port Alfred -33.5906   26.8910     13.07     overcast clouds        61
# 5     Yinchuan  38.4681  106.2731     23.58           clear sky        50
# 6     Kerepehi -37.3000  175.5333     16.15          few clouds        57
# 7  Provideniya  64.3833 -173.3000      9.74     overcast clouds        76
# 8   Walvis Bay -22.9575   14.5053     11.72           clear sky        87
# 9   Bredasdorp -34.5322   20.0403      9.60          few clouds        87
#
#    Cloudiness  Wind Speed Country
# 0           0        2.90      CL
# 1          75        4.63      CA
# 2         100        8.83      RU
# 3           0        1.79      ZA
# 4          89        3.32      ZA
# 5           2        2.45      CN
# 6          15        5.37      NZ
# 7          95        4.01      RU
# 8           0        2.57      NA
# 9          18        1.03      ZA

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lebu      CL -37.6167  -73.6500      7.80        87           0
# 1  Yellowknife      CA  62.4560 -114.3525     20.29        64          75
# 2   Chokurdakh      RU  70.6333  147.9167      7.62        67         100
# 3    Cape Town      ZA -33.9258   18.4232     10.49        75           0
# 4  Port Alfred      ZA -33.5906   26.8910     13.07        61          89
# 5     Yinchuan      CN  38.4681  106.2731     23.58        50           2
# 6     Kerepehi      NZ -37.3000  175.5333     16.15        57          15
# 7  Provideniya      RU  64.3833 -173.3000      9.74        76          95
# 8   Walvis Bay      NA -22.9575   14.5053     11.72        87           0
# 9   Bredasdorp      ZA -34.5322   20.0403      9.60        87          18
#
#    Wind Speed Current Description
# 0        2.90           clear sky
# 1        4.63       broken clouds
# 2        8.83     overcast clouds
# 3        1.79           clear sky
# 4        3.32     overcast clouds
# 5        2.45           clear sky
# 6        5.37          few clouds
# 7        4.01     overcast clouds
# 8        2.57           clear sky
# 9        1.03          few clouds

# %%
 city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(r'C:\Users\tante\dabc\Week_6 Challenge\Weather_Database\WeatherPy_Database.csv', index = False)
